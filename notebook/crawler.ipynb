# %%
import requests
import time
from urllib.parse import urljoin
from bs4 import BeautifulSoup
from datetime import datetime, timezone, timedelta
from dateutil import parser
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from selenium.common.exceptions import NoSuchElementException
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from tenacity import retry, wait_exponential, stop_after_attempt, retry_if_exception_type
from common.db import SQLiteHook
from common.writer import Writer

class BaomoiCrawler:
    BASE_URL = "https://baomoi.com"
    LOCAL_TIMEZONE = timezone(timedelta(hours=7))

    def __init__(self, max_pages=200, topic="tin-moi", max_article_age_days=4):
        self.TOPIC_URL = f"{self.BASE_URL}/{topic}.epi"
        self.max_pages = max_pages
        self.max_article_age_days = max_article_age_days
        self.count = 0

        chrome_options = Options()
        # chrome_options.add_argument("--headless=new")
        chrome_options.add_argument("--no-sandbox")
        chrome_options.add_argument("--disable-dev-shm-usage")

        self.driver = webdriver.Chrome(
            service=Service(ChromeDriverManager().install()),
            options=chrome_options
        )

        self.cache = SQLiteHook()
        self.writer = Writer()

    def close(self):
        self.driver.quit()
        self.cache.close()

    @retry(
        wait=wait_exponential(multiplier=1, min=2, max=10),
        stop=stop_after_attempt(3),
        retry=retry_if_exception_type(requests.RequestException)
    )
    def fetch_html(self, url):
        response = requests.get(url, timeout=10)
        response.raise_for_status()
        return response.text

    def fetch_html_js_rendering(self, url):
        self.driver.get(url)
        time.sleep(2)

        last_height = self.driver.execute_script("return document.body.scrollHeight")
        scroll_pause_time = 1

        while True:
            try:
                load_more_div = self.driver.find_element(By.CSS_SELECTOR, "div.load-more")
                if load_more_div.is_displayed():
                    break
            except NoSuchElementException:
                pass

            self.driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
            time.sleep(scroll_pause_time)

            new_height = self.driver.execute_script("return document.body.scrollHeight")
            if new_height == last_height:
                break
            last_height = new_height

        return self.driver.page_source

    def extract_urls(self, html):
        soup = BeautifulSoup(html, "html.parser")
        urls = set()

        for a_tag in soup.select("h3 > a[href]"):
            href = a_tag.get("href")
            if href:
                url = urljoin(self.BASE_URL, href)
                urls.add(url)

        return list(urls)

    def extract_next_page_url(self, html):
        soup = BeautifulSoup(html, "html.parser")
        load_more_hrefs = soup.select("div.load-more a[href]")
        if load_more_hrefs:
            next_page_href = load_more_hrefs[-1].get("href")
            if next_page_href:
                return urljoin(self.BASE_URL, next_page_href)
        return None

    def parse_article_from_url(self, url) -> dict | None:
        html = self.fetch_html(url)
        if not html:
            return None

        soup = BeautifulSoup(html, "html.parser")

        title_tag = soup.find("h1")
        title = title_tag.text.strip() if title_tag else None

        crawled_time = datetime.now(self.LOCAL_TIMEZONE).isoformat()
        time_tag = soup.find("time", datetime=True)
        published_time = None
        if time_tag:
            try:
                dt = parser.isoparse(time_tag["datetime"])
                published_time = dt.astimezone(self.LOCAL_TIMEZONE).isoformat()
            except Exception:
                published_time = None

        content_div = soup.find("div", class_="content-body")
        author_paragraphs = []
        content_paragraphs = []

        if content_div:
            for p in content_div.find_all("p"):
                if "body-author" in p.get("class", []):
                    author_paragraphs.append(p.text.strip())
                else:
                    content_paragraphs.append(p.text.strip())

        author = " ".join(author_paragraphs) if author_paragraphs else None
        content = " ".join(content_paragraphs) if content_paragraphs else None

        return {
            "title": title,
            "published_time": published_time,
            "crawled_time": crawled_time,
            "content": content,
            "author": author,
            "url": url,
        }

    def process_article_url(self, url) -> None:
        try:
            if self.cache.has_visited(url):
                return

            print(f"📰 Crawling article: {url}")
            article = self.parse_article_from_url(url)
            if not article:
                return

            if not article.get("published_time"):
                return

            published_time = datetime.fromisoformat(article["published_time"])
            crawled_time = datetime.fromisoformat(article["crawled_time"])
            article_age_days = (crawled_time - published_time).days
            if article_age_days > self.max_article_age_days:
                print(f"Skipping {url}: Expired article publish date")
                return

            if not article.get("content"):
                print("Skipping {url}: No content")
                return

            self.cache.mark_visited(url)
            self.writer.write_article(article)
            self.count += 1
        except Exception as e:
            print(f"Error scraping {url}: {e}")

    def run(self):
        start_url = self.TOPIC_URL

        while self.count < self.max_pages and start_url:
            print(f"🔎 Rendering page: {start_url}")
            html = self.fetch_html_js_rendering(start_url)
            article_urls = self.extract_urls(html)
            print(len(article_urls))
            start_url = self.extract_next_page_url(html)

            for article_url in article_urls:
                self.process_article_url(article_url)

            print(f"Count {self.count} articles processed")

        print(f"Finished. Total articles crawled: {self.count}")


if __name__ == "__main__":
    crawler = BaomoiCrawler()
    crawler.run()

    crawler.close()
# Out:
# 🔎 Rendering page: https://baomoi.com/tin-moi.epi
# 145
# 📰 Crawling article: https://baomoi.com/khap-noi-trong-tinh-ngay-28-6-2025-c52624522.epi
# 📰 Crawling article: https://baomoi.com/the-gioi-nua-dau-2025-dau-an-tong-thong-trump-c52581005.epi
# 📰 Crawling article: https://baomoi.com/vu-chay-xuong-tai-che-tai-hung-yen-it-nhat-hai-nguoi-nghi-da-tu-vong-c52624676.epi
# 📰 Crawling article: https://baomoi.com/tp-hcm-dieu-chinh-quy-hoach-tao-luc-hut-dau-tu-moi-c52624738.epi
# 📰 Crawling article: https://baomoi.com/gia-ca-phe-hom-nay-29-6-gia-ca-phe-robusta-va-arabica-tiep-tuc-giam-c52624710.epi
# 📰 Crawling article: https://baomoi.com/nghi-quyet-ve-thi-diem-mot-so-co-che-chinh-sach-dac-thu-phat-trien-thanh-pho-hai-phong-c52624742.epi
# 📰 Crawling article: https://baomoi.com/ban-tri-su-phat-giao-q-8-tong-ket-nhiem-ky-tri-an-dong-gop-cua-tang-ni-c52624697.epi
# 📰 Crawling article: https://baomoi.com/lu-doan-101-kiem-tra-ban-dan-that-6-thang-dau-nam-c52624681.epi
# 📰 Crawling article: https://baomoi.com/vo-si-nga-bi-tai-nan-chua-tung-co-bat-tinh-tren-san-dau-c52624750.epi
# 📰 Crawling article: https://baomoi.com/bao-giao-duc-va-thoi-dai-tap-trung-doi-moi-noi-dung-day-manh-chuyen-doi-so-c52624499.epi
# 📰 Crawling article: https://baomoi.com/nhieu-chu-tich-bi-thu-xa-o-nghe-an-bat-ngo-phai-quay-lai-lam-viec-sau-6-thang-nghi-huu-c52619381.epi
# 📰 Crawling article: https://baomoi.com/mot-chau-be-mat-tich-nghi-do-duoi-nuoc-tai-bai-bien-bai-chay-c52624726.epi
# 📰 Crawling article: https://baomoi.com/trieu-tap-them-10-doi-tuong-lien-quan-vu-cam-hung-khi-phong-xe-toc-do-cao-khoe-tren-tiktok-c52624634.epi
# 📰 Crawling article: https://baomoi.com/chu-dong-dao-tao-nhan-luc-duong-sat-toc-do-cao-c52624539.epi
# 📰 Crawling article: https://baomoi.com/kien-nghi-tang-gia-dat-nong-nghiep-bang-65-70-dat-o-c52624781.epi
# 📰 Crawling article: https://baomoi.com/khuyen-khich-tieu-dung-xanh-huong-den-ky-nguyen-ben-vung-c52624647.epi
# 📰 Crawling article: https://baomoi.com/chinh-thuc-chot-muc-luong-huu-moi-tu-ngay-1-7-c52621467.epi
# 📰 Crawling article: https://baomoi.com/chay-lon-tai-hung-yen-it-nhat-4-nguoi-tu-vong-c52624592.epi
# 📰 Crawling article: https://baomoi.com/khoi-cong-du-an-mo-rong-doan-cao-toc-thanh-pho-ho-chi-minh-long-thanh-vao-ngay-19-8-c52624523.epi
# 📰 Crawling article: https://baomoi.com/khai-mac-hoi-nghi-tu-phap-cac-tinh-co-chung-duong-bien-gioi-viet-nam-trung-quoc-lan-thu-nhat-c52624641.epi
# 📰 Crawling article: https://baomoi.com/le-trao-giai-va-be-mac-giai-golf-toi-yeu-viet-nam-c52624532.epi
# 📰 Crawling article: https://baomoi.com/hai-doi-tuong-mua-ban-ma-tuy-linh-an-35-nam-tu-c52624771.epi
# 📰 Crawling article: https://baomoi.com/ba-ria-vung-tau-gieo-mam-xanh-cho-tuong-lai-nong-thon-c52624650.epi
# 📰 Crawling article: https://baomoi.com/so-ket-3-nam-phoi-hop-hoat-dong-giua-vung-4-hai-quan-voi-cong-doan-y-te-viet-nam-c52624591.epi
# 📰 Crawling article: https://baomoi.com/tp-ho-chi-minh-se-tro-thanh-sieu-do-thi-sau-ngay-1-7-c52624619.epi
# 📰 Crawling article: https://baomoi.com/nu-streamer-xinh-dep-gay-sot-vi-mot-chi-tiet-la-ma-quen-c52624734.epi
# 📰 Crawling article: https://baomoi.com/chung-ket-nam-cuoc-thi-master-english-master-your-life-c52624744.epi
# 📰 Crawling article: https://baomoi.com/ky-vong-sau-sap-nhap-3-dia-phuong-trong-diem-c52624632.epi
# 📰 Crawling article: https://baomoi.com/ai-hoa-quyen-voi-thoi-trang-trong-mat-mot-nghe-si-thiet-ke-c52624583.epi
# 📰 Crawling article: https://baomoi.com/lan-dau-tien-cuc-csgt-co-nu-pho-cuc-truong-c52624770.epi
# 📰 Crawling article: https://baomoi.com/nhan-rong-mo-hinh-giao-duc-suc-khoe-sinh-san-va-tinh-duc-cho-sinh-vien-c52624616.epi
# 📰 Crawling article: https://baomoi.com/qatar-da-giup-dan-xep-lenh-ngung-ban-iran-israel-nhu-the-nao-c52591199.epi
# 📰 Crawling article: https://baomoi.com/anh-hiem-he-lo-cuoc-song-nguoi-lao-dong-o-my-nhieu-nam-truoc-c52624617.epi
# 📰 Crawling article: https://baomoi.com/thep-viet-thoat-thue-chong-ban-gia-cua-malaysia-c52624833.epi
# 📰 Crawling article: https://baomoi.com/hdnd-tinh-hau-giang-thong-qua-4-nghi-quyet-o-ky-hop-cuoi-c52624562.epi
# 📰 Crawling article: https://baomoi.com/bo-truong-bo-cong-an-trao-quyet-dinh-cho-34-giam-doc-cong-an-cac-tinh-thanh-c52624660.epi
# 📰 Crawling article: https://baomoi.com/quy-che-hoat-dong-cua-hoi-dong-tuyen-chon-giam-sat-tham-phan-quoc-gia-c52624661.epi
# 📰 Crawling article: https://baomoi.com/iran-dua-tang-cac-tuong-linh-va-nha-khoa-hoc-hat-nhan-c52624615.epi
# 📰 Crawling article: https://baomoi.com/doan-si-quan-tre-quan-doi-nhan-dan-lao-giao-luu-voi-bo-tu-lenh-vung-canh-sat-bien-2-c52624764.epi
# 📰 Crawling article: https://baomoi.com/ban-tin-y-te-28-6-nhan-cau-bien-dang-do-bi-hang-xom-dung-dua-nhua-dam-vao-mat-c52624628.epi
# 📰 Crawling article: https://baomoi.com/song-thoi-thuong-giua-long-do-thi-bien-binh-son-c52624618.epi
# 📰 Crawling article: https://baomoi.com/du-bao-thoi-tiet-theo-don-vi-hanh-chinh-2-cap-c52624755.epi
# 📰 Crawling article: https://baomoi.com/be-boi-hut-hoi-mua-cao-diem-chuyen-gia-noi-gi-c52624666.epi
# 📰 Crawling article: https://baomoi.com/thong-qua-quy-che-quan-ly-kien-truc-phuong-an-khe-an-binh-va-xa-cuu-an-c52624557.epi
# 📰 Crawling article: https://baomoi.com/thieu-tuong-tran-xuan-anh-giu-chuc-giam-doc-cong-an-tinh-hung-yen-sau-hop-nhat-c52624815.epi
# 📰 Crawling article: https://baomoi.com/nghi-quyet-thanh-lap-toa-an-nhan-dan-cap-tinh-toa-an-nhan-dan-khu-vuc-c52624758.epi
# 📰 Crawling article: https://baomoi.com/lu-doan-146-phat-dong-chien-dich-tinh-nguyen-he-2025-c52624627.epi
# 📰 Crawling article: https://baomoi.com/huyen-thuong-tin-don-nhan-danh-hieu-dat-chuan-nong-thon-moi-nang-cao-nam-2024-c52624705.epi
# 📰 Crawling article: https://baomoi.com/lan-gio-moi-canh-tranh-phan-khuc-suv-co-b-c52624766.epi
# 📰 Crawling article: https://baomoi.com/thai-phu-sinh-con-o-tuan-31-vi-can-benh-truyen-nhiem-de-mac-c52624516.epi
# 📰 Crawling article: https://baomoi.com/thuyet-phuc-nham-anh-huong-tich-cuc-toi-nguoi-khac-c52624635.epi
# 📰 Crawling article: https://baomoi.com/cac-ben-co-thuc-su-dat-muc-tieu-khi-cuoc-chien-12-ngay-israel-iran-ha-man-c52595386.epi
# 📰 Crawling article: https://baomoi.com/nguoi-thai-lan-bieu-tinh-ram-ro-doi-thu-tuong-tu-chuc-c52624560.epi
# 📰 Crawling article: https://baomoi.com/ra-mat-suv-chau-au-skoda-kushaq-san-xuat-tai-viet-nam-gia-tu-589-trieu-dong-c52624782.epi
# 📰 Crawling article: https://baomoi.com/cuu-ngoi-sao-man-united-doi-dau-nhau-tren-san-pickleball-c52624629.epi
# 📰 Crawling article: https://baomoi.com/tp-hcm-tap-nap-rao-ban-can-ho-dich-vu-c52624779.epi
# 📰 Crawling article: https://baomoi.com/khanh-thanh-3-can-nha-chu-thap-do-va-tang-qua-ho-ngheo-kho-khan-c52624525.epi
# 📰 Crawling article: https://baomoi.com/som-hoan-thien-trien-khai-luat-to-chuc-chinh-quyen-dia-phuong-c52624630.epi
# 📰 Crawling article: https://baomoi.com/cong-an-ha-noi-tim-bi-hai-vu-nhan-tien-chay-bien-che-xin-vao-truong-cong-an-c52624748.epi
# 📰 Crawling article: https://baomoi.com/gia-ve-lien-thong-giua-metro-va-xe-buyt-tai-ha-noi-se-la-bao-nhieu-c52624719.epi
# 📰 Crawling article: https://baomoi.com/ke-phan-dien-moi-cua-nato-c52600427.epi
# 📰 Crawling article: https://baomoi.com/tao-thuan-loi-cho-nguoi-dan-trong-thu-tuc-dat-dai-c52624778.epi
# 📰 Crawling article: https://baomoi.com/tu-an-do-iran-toi-ukraine-the-gioi-buoc-vao-giai-doan-rui-ro-leo-thang-kieu-moi-c52618641.epi
# 📰 Crawling article: https://baomoi.com/nganh-y-te-giu-nguyen-cac-don-vi-chuyen-mon-sau-khi-hop-nhat-c52624495.epi
# 📰 Crawling article: https://baomoi.com/sua-doi-bo-sung-mot-so-dieu-cua-nghi-quyet-ve-bac-va-so-luong-tham-phan-tand-c52624711.epi
# 📰 Crawling article: https://baomoi.com/nato-buoc-vao-vung-thu-thach-c52608278.epi
# 📰 Crawling article: https://baomoi.com/thi-truong-tien-te-6-thang-dau-nam-tin-phieu-tai-xuat-khi-ty-gia-dong-loat-di-len-eur-tang-vot-15-c52624722.epi
# 📰 Crawling article: https://baomoi.com/dau-tho-danh-dau-tuan-giam-gia-manh-nhat-trong-ba-nam-c52624529.epi
# 📰 Crawling article: https://baomoi.com/tong-giam-doc-unesco-san-sang-cung-viet-nam-chia-se-tam-nhin-chien-luoc-ve-van-hoa-ra-the-gioi-c52624652.epi
# 📰 Crawling article: https://baomoi.com/chap-hanh-vien-pham-tien-dung-ke-ve-vu-an-kinh-dien-keo-dai-gan-40-nam-c52624756.epi
# 📰 Crawling article: https://baomoi.com/lam-dong-ky-hop-dong-xay-dung-cao-toc-bao-loc-lien-khuong-12-000-ty-dong-c52624653.epi
# 📰 Crawling article: https://baomoi.com/hang-hoa-ap-dung-thue-vat-8-phai-khai-ma-rieng-tu-ngay-1-7-c52624713.epi
# 📰 Crawling article: https://baomoi.com/bien-chung-nguy-hiem-cua-benh-gian-tinh-mach-c52624644.epi
# 📰 Crawling article: https://baomoi.com/ha-noi-dong-bo-hieu-qua-trong-sap-xep-don-vi-hanh-chinh-cap-xa-c52624718.epi
# 📰 Crawling article: https://baomoi.com/xep-hang-2-di-tich-lich-su-cap-tinh-gan-voi-luc-luong-cong-an-nhan-dan-vu-trang-tinh-quang-tri-c52624512.epi
# 📰 Crawling article: https://baomoi.com/kiem-tra-viec-van-hanh-chinh-quyen-dia-phuong-2-cap-o-lai-chau-c52624599.epi
# 📰 Crawling article: https://baomoi.com/canh-bao-nguy-co-lu-quet-va-sat-lo-dat-o-bac-bo-do-mua-lon-keo-dai-c52624545.epi
# 📰 Crawling article: https://baomoi.com/tu-thien-duong-hop-tac-den-vuc-tham-doi-dau-c52592976.epi
# 📰 Crawling article: https://baomoi.com/thap-sang-binh-dang-gioi-kien-tao-tuong-lai-cho-phu-nu-va-tre-em-dan-toc-thieu-so-c52624749.epi
# 📰 Crawling article: https://baomoi.com/thai-son-nam-bao-ve-thanh-cong-chuc-vo-dich-giai-futsal-hdbank-vo-dich-quoc-gia-c52624662.epi
# 📰 Crawling article: https://baomoi.com/thai-lan-bat-ngo-truoc-buoc-di-cua-ong-hun-sen-c52619525.epi
# 📰 Crawling article: https://baomoi.com/canada-yeu-cau-hikvision-cua-trung-quoc-dung-hoat-dong-c52624723.epi
# 📰 Crawling article: https://baomoi.com/cai-dep-mau-phai-thi-khong-co-quyen-doi-hoi-c52624597.epi
# 📰 Crawling article: https://baomoi.com/thap-hy-vong-cho-cac-cap-vo-chong-hiem-muon-kho-khan-c52624785.epi
# 📰 Crawling article: https://baomoi.com/phat-hien-som-nhieu-ca-benh-man-tinh-nho-sang-loc-qua-ai-c52624733.epi
# 📰 Crawling article: https://baomoi.com/xay-dung-cau-noi-hop-tac-tai-chinh-viet-nam-anh-c52624703.epi
# 📰 Crawling article: https://baomoi.com/mo-ra-huong-phat-trien-moi-cho-hop-tac-giua-hai-nuoc-viet-nam-tay-ban-nha-c52624515.epi
# 📰 Crawling article: https://baomoi.com/nghe-si-huu-chau-ra-mat-but-ky-chan-dung-c52624554.epi
# 📰 Crawling article: https://baomoi.com/cong-an-tinh-cao-bang-to-chuc-ky-thi-sat-hach-cap-giay-phep-lai-xe-o-to-c52624720.epi
# 📰 Crawling article: https://baomoi.com/thai-son-bac-chua-the-soan-ngoi-cua-thai-son-nam-tphcm-c52624649.epi
# 📰 Crawling article: https://baomoi.com/ban-noi-chinh-trung-uong-no-luc-nang-cao-chat-luong-cong-tac-tham-muu-chien-luoc-phong-chong-tham-nhung-lang-phi-tieu-cuc-va-cai-cach-tu-phap-c52624638.epi
# 📰 Crawling article: https://baomoi.com/thoi-tiet-ngay-mai-29-6-bac-bo-va-trung-bo-co-mua-to-va-dong-c52624709.epi
# 📰 Crawling article: https://baomoi.com/dot-pha-moi-benh-nhan-ung-thu-co-the-xuat-vien-sau-2-ngay-dieu-tri-c52624712.epi
# 📰 Crawling article: https://baomoi.com/thong-tin-can-biet-cho-nguoi-dung-sac-du-phong-anker-c52624658.epi
# 📰 Crawling article: https://baomoi.com/dbqh-ky-vong-ve-nhung-quyet-sach-kinh-te-c52624739.epi
# 📰 Crawling article: https://baomoi.com/lang-son-don-nhan-danh-hieu-cong-vien-dia-chat-toan-cau-unesco-c52624544.epi
# 📰 Crawling article: https://baomoi.com/khang-dinh-vai-tro-tong-tham-muu-cua-van-phong-ubnd-thanh-pho-c52624502.epi
# 📰 Crawling article: https://baomoi.com/40-chu-dau-tu-cham-bao-tri-duong-bo-c52624633.epi
# 📰 Crawling article: https://baomoi.com/khong-can-chi-tien-mua-giuong-dat-do-khoan-dang-dau-tu-lai-la-chiec-nem-c52624585.epi
# 📰 Crawling article: https://baomoi.com/lam-dong-san-sang-buoc-vao-ky-nguyen-moi-c52624534.epi
# 📰 Crawling article: https://baomoi.com/ba-ben-ba-chien-thang-cuc-dien-moi-sau-don-tra-dua-cua-iran-c52583499.epi
# 📰 Crawling article: https://baomoi.com/khai-mac-giai-bong-chuyen-nu-quoc-te-vtv-ferroli-cup-nam-2025-c52624812.epi
# 📰 Crawling article: https://baomoi.com/duc-dieu-tiem-kich-bam-duoi-may-bay-trinh-sat-nga-tren-bien-baltic-c52624595.epi
# 📰 Crawling article: https://baomoi.com/lang-nghe-y-kien-dang-vien-phuong-dien-bien-quan-ba-dinh-chuyen-sinh-hoat-dang-ve-phuong-hoan-kiem-moi-c52624746.epi
# 📰 Crawling article: https://baomoi.com/futsal-hdbank-vdqg-2025-thai-son-nam-hoa-kich-tinh-vo-dich-nho-chi-so-phu-c52624600.epi
# 📰 Crawling article: https://baomoi.com/nghi-quyet-thi-diem-mot-so-co-che-chinh-sach-dac-thu-phat-trien-hai-phong-c52624625.epi
# 📰 Crawling article: https://baomoi.com/dong-chi-nguyen-van-kim-lan-tai-dac-cu-chuc-bi-thu-dang-uy-cong-ty-cp-tap-doan-truong-hai-c52624521.epi
# 📰 Crawling article: https://baomoi.com/vu-chay-xuong-tai-che-tai-hung-yen-co-it-nhat-hai-nguoi-nghi-da-tu-vong-c52624664.epi
# 📰 Crawling article: https://baomoi.com/hoc-sinh-su-dung-ai-cong-cu-ho-tro-hay-lam-suy-yeu-tu-duy-c52624701.epi
# 📰 Crawling article: https://baomoi.com/hai-phong-chinh-thuc-ra-mat-tour-dem-dau-thieng-hang-kenh-c52624612.epi
# 📰 Crawling article: https://baomoi.com/khi-chinh-sach-la-don-bay-tang-truong-ben-vung-c52624506.epi
# 📰 Crawling article: https://baomoi.com/canh-bao-cac-tai-nan-bong-mat-thuong-gap-c52624740.epi
# 📰 Crawling article: https://baomoi.com/malaysia-quang-ba-the-he-sau-rieng-moi-ke-nghiep-musang-king-c52624621.epi
# 📰 Crawling article: https://baomoi.com/canh-bao-khong-dung-thuc-pham-bao-ve-suc-khoe-an-vi-moc-linh-c52624724.epi
# 📰 Crawling article: https://baomoi.com/dai-hoi-chi-bo-doan-luat-su-tinh-lan-thu-v-nhiem-ky-2025-2030-c52624526.epi
# 📰 Crawling article: https://baomoi.com/ong-trump-san-sang-can-nhac-nem-bom-iran-lan-nua-c52618493.epi
# 📰 Crawling article: https://baomoi.com/18-doanh-nghiep-sap-chot-quyen-chia-co-tuc-c52624736.epi
# 📰 Crawling article: https://baomoi.com/sau-gan-2-thap-ky-trien-khai-khu-cong-nghiep-my-trung-o-nam-dinh-tro-thanh-noi-tha-trau-bo-c52624578.epi
# 📰 Crawling article: https://baomoi.com/nhung-nguoi-khuyet-tat-vuot-nghich-canh-c52624513.epi
# 📰 Crawling article: https://baomoi.com/thoat-khoi-phien-toai-tu-cuoc-goi-so-la-c52624509.epi
# 📰 Crawling article: https://baomoi.com/be-trai-8-tuoi-mat-tich-khi-tam-bien-cung-gia-dinh-o-ha-long-c52624765.epi
# 📰 Crawling article: https://baomoi.com/vang-nhan-trong-nuoc-ngay-28-6-giam-200-000-700-000-dong-kg-c52624519.epi
# 📰 Crawling article: https://baomoi.com/khao-sat-lua-chon-cua-nguoi-ukraine-giua-ong-zelensky-va-ong-zaluzhny-neu-to-chuc-bau-cu-c52620684.epi
# 📰 Crawling article: https://baomoi.com/lam-dong-khoi-to-doi-tuong-kich-dong-nguoi-dan-tu-tap-dong-nguoi-gay-roi-trat-tu-cong-cong-c52624537.epi
# 📰 Crawling article: https://baomoi.com/dai-ta-bui-quang-binh-lam-giam-doc-cong-an-tp-hai-phong-c52624602.epi
# 📰 Crawling article: https://baomoi.com/tin-the-gioi-21h-ngay-28-6-nga-don-quan-den-mat-tran-nong-nhat-tren-chien-truong-ukraine-c52624707.epi
# Skipping {url}: No content
# 📰 Crawling article: https://baomoi.com/nghi-quyet-ve-viec-thi-hanh-luat-to-chuc-cua-toa-an-va-vien-kiem-sat-c52624659.epi
# 📰 Crawling article: https://baomoi.com/vu-chay-xuong-tai-hung-yen-dam-chay-van-bung-manh-it-nhat-1-nguoi-tu-vong-c52624683.epi
# 📰 Crawling article: https://baomoi.com/chay-nha-xuong-khien-4-nguoi-tu-vong-c52624610.epi
# 📰 Crawling article: https://baomoi.com/quang-ninh-no-luc-tim-kiem-be-trai-mat-tich-khi-tam-bien-c52624804.epi
# 📰 Crawling article: https://baomoi.com/linh-vuc-xay-dung-phai-thanh-dong-luc-tang-truong-thu-do-c52624715.epi
# 📰 Crawling article: https://baomoi.com/bat-cap-ve-bien-bao-duong-bo-tiep-tuc-duoc-xu-ly-c52624631.epi
# 📰 Crawling article: https://baomoi.com/4-nguoi-tu-vong-trong-vu-chay-tai-xuong-tai-che-phe-lieu-o-hung-yen-c52624690.epi
# 📰 Crawling article: https://baomoi.com/nang-cao-cong-tac-an-ninh-cang-bien-tai-cang-da-nang-c52624835.epi
# 📰 Crawling article: https://baomoi.com/phat-huy-truyen-thong-nguoi-dai-bieu-dan-cu-tiep-lua-cho-the-he-tre-viet-tiep-nhung-trang-su-ve-vang-cua-que-huong-dat-nuoc-c52624803.epi
# 📰 Crawling article: https://baomoi.com/dau-thieng-hang-kenh-khuc-tram-cua-ky-uc-vong-giua-long-thanh-pho-cang-c52624823.epi
# 📰 Crawling article: https://baomoi.com/dong-dien-cong-trinh-tram-bien-ap-220kv-ba-thien-tang-cuong-dam-bao-dien-cho-tinh-vinh-phuc-c52624754.epi
# 📰 Crawling article: https://baomoi.com/da-nang-quang-nam-doan-ket-san-sang-cho-buoc-chuyen-minh-lich-su-c52624800.epi
# 📰 Crawling article: https://baomoi.com/soc-nu-sinh-ha-noi-tu-vong-sau-khi-nan-mun-va-boi-thuoc-khong-ro-nguon-goc-c52624533.epi
# 📰 Crawling article: https://baomoi.com/nhan-dien-su-lanh-dao-cua-dang-doi-voi-bao-chi-la-tat-yeu-khach-quan-c52624546.epi
# 📰 Crawling article: https://baomoi.com/hung-yen-chay-nha-xuong-4-nguoi-tu-vong-3-nguoi-bi-thuong-c52624582.epi
# 📰 Crawling article: https://baomoi.com/giai-teqball-vo-dich-tp-hcm-lam-tien-de-cho-sea-games-33-c52624542.epi
# 📰 Crawling article: https://baomoi.com/nguoi-dan-mong-som-cai-tao-khu-tap-the-vinh-ho-c52624679.epi
# 📰 Crawling article: https://baomoi.com/chai-nuoc-giup-bui-tien-dung-can-11-m-cua-cong-phuong-c52617896.epi
# 📰 Crawling article: https://baomoi.com/cha-de-danh-con-gay-thuong-tich-bi-xu-phat-30-trieu-dong-c52624682.epi
# Count 144 articles processed
# 🔎 Rendering page: https://baomoi.com/tin-moi/trang10.epi
# 81
# 📰 Crawling article: https://baomoi.com/luat-hoa-no-xau-phao-cuu-sinh-loi-nhuan-ngan-hang-c52624488.epi
# 📰 Crawling article: https://baomoi.com/han-quoc-kiem-soat-ung-dung-duoc-tai-san-cua-samsung-c52624377.epi
# 📰 Crawling article: https://baomoi.com/vu-chay-o-hung-yen-nan-nhan-rat-nang-chuyen-len-ha-noi-co-2-nguoi-bong-98-co-the-c52624451.epi
# 📰 Crawling article: https://baomoi.com/nang-tam-san-pham-dia-phuong-thanh-thuong-hieu-quoc-gia-c52624390.epi
# 📰 Crawling article: https://baomoi.com/quang-binh-khan-truong-bo-tri-nha-o-cong-vu-cho-can-bo-quang-tri-sau-khi-sap-nhap-tinh-c52624454.epi
# 📰 Crawling article: https://baomoi.com/quai-thu-rodri-tro-lai-c52624414.epi
# 📰 Crawling article: https://baomoi.com/tu-vong-khi-di-hai-lan-rung-o-lam-dong-c52624430.epi
# 📰 Crawling article: https://baomoi.com/thai-lan-hang-nghin-nguoi-bieu-tinh-yeu-cau-thu-tuong-paetongtarn-tu-chuc-c52624575.epi
# 📰 Crawling article: https://baomoi.com/unesco-tiep-tuc-dong-hanh-ve-van-hoa-thuc-day-nhung-gia-tri-cot-loi-cua-viet-nam-ra-the-gioi-c52624387.epi
# 📰 Crawling article: https://baomoi.com/rung-minh-bai-thuoc-nam-chua-la-ngon-cua-lang-bam-khien-benh-nhan-tu-vong-c52624498.epi
# 📰 Crawling article: https://baomoi.com/ngoc-lac-dau-tu-xay-dung-thiet-che-van-hoa-co-so-c52624466.epi
# 📰 Crawling article: https://baomoi.com/lam-dong-phat-hien-nguoi-dan-ong-tu-vong-trong-rung-sau-c52624411.epi
# 📰 Crawling article: https://baomoi.com/yeu-thuong-su-hoc-c52624408.epi
# 📰 Crawling article: https://baomoi.com/pho-thu-tuong-se-kiem-tra-cac-du-an-phuc-vu-apec-2027-c52624484.epi
# 📰 Crawling article: https://baomoi.com/vtv-cup-tung-bung-khai-mac-tuyen-viet-nam-tu-tin-chien-thang-c52624459.epi
# 📰 Crawling article: https://baomoi.com/nhung-htx-tien-phong-dua-san-pham-hoi-nhap-thi-truong-c52624389.epi
# 📰 Crawling article: https://baomoi.com/bua-sang-tron-vi-voi-to-bun-bo-suon-cay-o-quan-1-c52624417.epi
# 📰 Crawling article: https://baomoi.com/quang-ninh-cong-bo-quyet-dinh-thanh-lap-dang-bo-mat-tran-to-quoc-c52624483.epi
# 📰 Crawling article: https://baomoi.com/triet-pha-duong-day-ma-tuy-lien-tinh-bat-giu-hai-doi-tuong-c52624589.epi
# 📰 Crawling article: https://baomoi.com/ban-tin-toi-28-6-chu-tich-nuoc-luong-cuong-tiep-xuc-cu-tri-tai-tphcm-c52624428.epi
# Skipping {url}: No content
# 📰 Crawling article: https://baomoi.com/truc-linh-va-dan-hoa-hau-viet-nam-theo-duoi-dai-hoc-nao-c52624517.epi
# 📰 Crawling article: https://baomoi.com/620-bao-bo-can-sa-trong-vuon-sau-rieng-o-thai-lan-c52624473.epi
# 📰 Crawling article: https://baomoi.com/nhieu-xa-phuong-chinh-trang-tru-so-moi-c52624485.epi
# 📰 Crawling article: https://baomoi.com/quang-binh-san-sang-bo-tri-nha-o-cong-vu-cho-can-bo-quang-tri-sau-khi-sap-nhap-tinh-c52624579.epi
# 📰 Crawling article: https://baomoi.com/khong-de-co-quan-nha-nuoc-la-vung-tru-an-an-toan-cho-can-bo-yeu-kem-c52624471.epi
# 📰 Crawling article: https://baomoi.com/dai-ta-bui-quang-binh-giu-chuc-giam-doc-cong-an-tp-hai-phong-c52624469.epi
# 📰 Crawling article: https://baomoi.com/lang-son-vien-ngoc-moi-tren-ban-do-cong-vien-dia-chat-toan-cau-unesco-c52624396.epi
# 📰 Crawling article: https://baomoi.com/ha-noi-ket-qua-thi-10-co-cong-bo-som-hon-du-kien-c52624588.epi
# 📰 Crawling article: https://baomoi.com/xiaomi-ra-mat-xe-dien-moi-co-the-khien-tesla-dieu-dung-c52624489.epi
# Skipping {url}: No content
# 📰 Crawling article: https://baomoi.com/thu-tuong-phat-dong-phong-trao-toan-dan-thi-dua-lam-giau-c52624503.epi
# 📰 Crawling article: https://baomoi.com/lam-dong-dieu-chinh-phuong-an-bo-tri-tru-so-lam-viec-sau-sap-xep-hanh-chinh-cap-tinh-c52624384.epi
# 📰 Crawling article: https://baomoi.com/thu-tuong-pham-minh-chinh-phat-dong-phong-trao-toan-dan-thi-dua-lam-giau-c52624379.epi
# 📰 Crawling article: https://baomoi.com/nga-kiem-soat-khu-vuc-giau-lithium-nhat-chau-au-tai-mien-dong-ukraine-c52624494.epi
# 📰 Crawling article: https://baomoi.com/khoi-cong-hai-du-an-trong-diem-cua-tinh-thai-binh-c52624721.epi
# 📰 Crawling article: https://baomoi.com/nam-bao-ve-23-tuoi-phai-chay-than-suot-doi-vi-thoi-quen-pho-bien-c52624443.epi
# 📰 Crawling article: https://baomoi.com/cac-bi-cao-trong-vu-an-phuc-son-noi-loi-hoi-han-truoc-khi-toa-nghi-an-c52624404.epi
# 📰 Crawling article: https://baomoi.com/ivanka-trump-noi-bat-trong-dam-cuoi-ty-phu-jeff-bezos-c52624510.epi
# 📰 Crawling article: https://baomoi.com/giot-nuoc-mat-muon-mang-trong-phong-xu-an-vu-tap-doan-phuc-son-c52624461.epi
# 📰 Crawling article: https://baomoi.com/chuong-trinh-tuong-niem-nghe-thuat-tran-van-khe-mot-doi-voi-am-nhac-dan-toc-c52624464.epi
# 📰 Crawling article: https://baomoi.com/becamex-len-ke-hoach-phat-hanh-2-500-ty-dong-trai-phieu-va-tra-co-tuc-bang-co-phieu-c52624412.epi
# 📰 Crawling article: https://baomoi.com/ba-hoang-thi-thuy-lan-xin-loi-nguoi-dan-vinh-phuc-mong-duoc-tha-thu-c52624514.epi
# 📰 Crawling article: https://baomoi.com/loai-ca-nha-ngheo-hoa-dac-san-hon-nua-trieu-dong-kg-c52624388.epi
# 📰 Crawling article: https://baomoi.com/cong-dong-nguoi-viet-tai-israel-an-toan-dan-on-dinh-cuoc-song-c52624449.epi
# 📰 Crawling article: https://baomoi.com/david-de-gea-treu-choc-ronaldo-c52624413.epi
# 📰 Crawling article: https://baomoi.com/loi-ich-cua-qua-bo-voi-tim-mach-va-cong-thuc-nau-an-de-dang-c52624371.epi
# 📰 Crawling article: https://baomoi.com/phat-hien-thi-the-mac-ket-duoi-chan-dap-thuy-dien-o-tuyen-quang-c52624465.epi
# 📰 Crawling article: https://baomoi.com/vietjet-mo-loat-3-duong-bay-ket-noi-thanh-hoa-voi-da-lat-buon-ma-thuot-can-tho-c52624376.epi
# 📰 Crawling article: https://baomoi.com/bo-truong-bo-cong-an-trao-quyet-dinh-cho-23-giam-doc-cong-an-dia-phuong-sau-sap-nhap-c52624437.epi
# 📰 Crawling article: https://baomoi.com/ung-dung-tri-tue-nhan-tao-trong-cong-tac-toa-an-huu-ich-nhung-c52624407.epi
# 📰 Crawling article: https://baomoi.com/ha-tinh-xac-nhan-chia-tay-hlv-nguyen-thanh-cong-c52624421.epi
# 📰 Crawling article: https://baomoi.com/ve-sinh-moi-truong-lam-dep-duong-pho-chao-mung-le-cong-bo-sap-xep-don-vi-hanh-chinh-cap-xa-c52624492.epi
# 📰 Crawling article: https://baomoi.com/thanh-hoa-cong-an-vao-cuoc-dieu-tra-vu-hai-nhom-nu-sinh-chem-nhau-c52624478.epi
# 📰 Crawling article: https://baomoi.com/loai-ran-co-xua-lon-khung-khiep-tung-song-o-an-do-c52624486.epi
# 📰 Crawling article: https://baomoi.com/indonesia-malaysia-cung-co-vai-tro-khu-vuc-thuc-day-hop-tac-xu-ly-xung-dot-c52624470.epi
# 📰 Crawling article: https://baomoi.com/song-tot-doi-dep-dao-trong-dong-bao-cong-giao-huyen-nga-son-c52624426.epi
# 📰 Crawling article: https://baomoi.com/du-hoc-sinh-gop-phan-quang-ba-hinh-anh-viet-nam-tai-lao-c52624497.epi
# 📰 Crawling article: https://baomoi.com/bo-y-te-canh-bao-nguoi-tieu-dung-khong-su-dung-san-pham-bao-ve-suc-khoe-an-vi-moc-linh-c52624453.epi
# 📰 Crawling article: https://baomoi.com/bo-nhiem-tan-giam-doc-cong-an-tp-hai-phong-c52624518.epi
# 📰 Crawling article: https://baomoi.com/ban-thuong-vu-tinh-uy-khanh-hoa-chi-dao-tap-trung-hoan-thanh-sap-xep-to-chuc-bo-may-va-don-vi-hanh-chinh-c52624429.epi
# 📰 Crawling article: https://baomoi.com/pho-thu-tuong-nguyen-chi-dung-chinh-phu-ho-tro-toi-da-cac-du-an-ha-tang-phuc-vu-apec-2027-c52624570.epi
# 📰 Crawling article: https://baomoi.com/tu-vi-12-cung-hoang-dao-29-6-bach-duong-bi-loi-dung-c52624442.epi
# 📰 Crawling article: https://baomoi.com/tiep-tuc-day-manh-phoi-hop-hieu-qua-cham-soc-suc-khoe-can-bo-chien-si-vung-4-hai-quan-c52624422.epi
# Count 204 articles processed
# Finished. Total articles crawled: 204
